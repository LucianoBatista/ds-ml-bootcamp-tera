# %% [markdown]
# ### Preparação de Dados - Sberbank

# %%
# !pip install rise
# Out:
# Collecting rise
#   Downloading rise-5.7.1-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: notebook>=6.0 in c:\programdata\anaconda3\lib\site-packages (from rise) (6.1.4)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (0.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (19.0.2)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (0.9.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (6.1.7)
# Requirement already satisfied: ipykernel in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (5.3.4)
# Requirement already satisfied: Send2Trash in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (1.5.0)
# Requirement already satisfied: nbformat in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (5.0.8)
# Requirement already satisfied: traitlets>=4.2.1 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (5.0.5)
# Requirement already satisfied: tornado>=5.0 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (6.0.4)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (6.0.7)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (2.11.2)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->rise) (4.6.3)
# Requirement already satisfied: cffi>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->rise) (1.14.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->rise) (1.15.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\programdata\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->rise) (0.5.7)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=6.0->rise) (2.8.1)
# Requirement already satisfied: ipython>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->rise) (7.19.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\programdata\anaconda3\lib\site-packages (from nbformat->notebook>=6.0->rise) (3.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (1.4.3)
# Requirement already satisfied: pygments>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (2.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (0.1.2)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (0.4.4)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (0.3)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=6.0->rise) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->notebook>=6.0->rise) (1.1.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=6.0->rise) (227)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=6.0->rise) (2.20)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (0.4.4)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (0.17.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (50.3.1.post20201107)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (3.0.8)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=6.0->rise) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=6.0->rise) (20.3.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=6.0->rise) (0.5.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=6.0->rise) (20.4)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=6.0->rise) (1.4.2)
# Requirement already satisfied: async-generator in c:\programdata\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=6.0->rise) (1.10)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (0.7.0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=6.0->rise) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=6.0->rise) (2.4.7)
# Installing collected packages: rise
# Successfully installed rise-5.7.1

# %%
# Libs essenciais para o tratamento da base inicial
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
features_a_manter = [
    # Sem muita discussão quanto a essas, são bem básicas
    'id', 'timestamp', 
    'full_sq', 'life_sq', 'floor', 'max_floor',
    'material', 'build_year', 'num_room', 'kitch_sq', 'state',
    #'product_type',
    'sub_area',
    # Filtrando demais features para termos algo em torno de 15?
    # População e áreas
    'area_m', 'raion_popul',
    # Quantidade de locais importantes por distrito
    'healthcare_centers_raion',
    'university_top_20_raion',
    'shopping_centers_raion',
    'oil_chemistry_raion',
    'nuclear_reactor_raion',
    
    # Distribuição da população
    'full_all',
    'young_all',
    'work_all',
    'ekder_all',
    # Distâncias a locais importantes
    'kremlin_km',
    'big_road1_km',
    'railroad_km',
    'zd_vokzaly_avto_km',
    'metro_km_avto',
    'metro_km_walk',
    'radiation_km',
    # Variável resposta!!!!
    'price_doc'
]

# %%
dados = pd.read_csv('../1. Dados/PrecosCasasSberbank/train.csv')[features_a_manter]

# %%
dados.state = dados.state.astype('category')
dados.material = dados.material.astype('category')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        30471 non-null  int64
#  1   timestamp                 30471 non-null  object
#  2   full_sq                   30471 non-null  int64
#  3   life_sq                   24088 non-null  float64
#  4   floor                     30304 non-null  float64
#  5   max_floor                 20899 non-null  float64
#  6   material                  20899 non-null  category
#  7   build_year                16866 non-null  float64
#  8   num_room                  20899 non-null  float64
#  9   kitch_sq                  20899 non-null  float64
#  10  state                     16912 non-null  category
#  11  sub_area                  30471 non-null  object
#  12  area_m                    30471 non-null  float64
#  13  raion_popul               30471 non-null  int64
#  14  healthcare_centers_raion  30471 non-null  int64
#  15  university_top_20_raion   30471 non-null  int64
#  16  shopping_centers_raion    30471 non-null  int64
#  17  oil_chemistry_raion       30471 non-null  object
#  18  nuclear_reactor_raion     30471 non-null  object
#  19  full_all                  30471 non-null  int64
#  20  young_all                 30471 non-null  int64
#  21  work_all                  30471 non-null  int64
#  22  ekder_all                 30471 non-null  int64
#  23  kremlin_km                30471 non-null  float64
#  24  big_road1_km              30471 non-null  float64
#  25  railroad_km               30471 non-null  float64
#  26  zd_vokzaly_avto_km        30471 non-null  float64
#  27  metro_km_avto             30471 non-null  float64
#  28  metro_km_walk             30446 non-null  float64
#  29  radiation_km              30471 non-null  float64
#  30  price_doc                 30471 non-null  int64
# dtypes: category(2), float64(14), int64(11), object(4)
# memory usage: 6.8+ MB

# %%
# Separando apenas os dados preenchidos para amostrar
dados_preenchidos = dados.dropna()
dados_restantes = dados.drop(dados_preenchidos.index)

# %%
# Separando 35% dos dados preenchidos como teste
amostra_teste = dados_preenchidos.sample(frac=0.35)
amostra_treino = dados_preenchidos.drop(amostra_teste.index)

# Concatenando com a base que possui missings
dados_final = pd.concat([dados_restantes,amostra_treino])

# %%
dados_restantes.isna().sum()
# Out:
# id                              0
# timestamp                       0
# full_sq                         0
# life_sq                      6383
# floor                         167
# max_floor                    9572
# material                     9572
# build_year                  13605
# num_room                     9572
# kitch_sq                     9572
# state                       13559
# sub_area                        0
# area_m                          0
# raion_popul                     0
# healthcare_centers_raion        0
# university_top_20_raion         0
# shopping_centers_raion          0
# oil_chemistry_raion             0
# nuclear_reactor_raion           0
# full_all                        0
# young_all                       0
# work_all                        0
# ekder_all                       0
# kremlin_km                      0
# big_road1_km                    0
# railroad_km                     0
# zd_vokzaly_avto_km              0
# metro_km_avto                   0
# metro_km_walk                  25
# radiation_km                    0
# price_doc                       0
# dtype: int64

# %%
# Tamanhos finais
print('Total Treino com dados preenchidos')
print(dados_final.shape)
print('Total Teste com dados preenchidos')
print(amostra_teste.shape)
# Out:
# Total Treino com dados preenchidos
# (25290, 31)
# Total Teste com dados preenchidos
# (5181, 31)

# %%
sns.distplot(dados_final.price_doc)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price_doc', ylabel='Density'>

# %%
sns.distplot(amostra_teste.price_doc)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price_doc', ylabel='Density'>

# %%
from scipy.stats import zscore
z_score = zscore(amostra_teste.select_dtypes(exclude='object'))
teste_z_score = np.abs(z_score) < 3
dados_full_no_out = amostra_teste[teste_z_score.all(axis=1)]

# %%
sns.distplot(dados_full_no_out.price_doc)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price_doc', ylabel='Density'>

# %%
dados_final.dtypes
# Out:
# id                             int64
# timestamp                     object
# full_sq                        int64
# life_sq                      float64
# floor                        float64
# max_floor                    float64
# material                    category
# build_year                   float64
# num_room                     float64
# kitch_sq                     float64
# state                       category
# sub_area                      object
# area_m                       float64
# raion_popul                    int64
# healthcare_centers_raion       int64
# university_top_20_raion        int64
# shopping_centers_raion         int64
# oil_chemistry_raion           object
# nuclear_reactor_raion         object
# full_all                       int64
# young_all                      int64
# work_all                       int64
# ekder_all                      int64
# kremlin_km                   float64
# big_road1_km                 float64
# railroad_km                  float64
# zd_vokzaly_avto_km           float64
# metro_km_avto                float64
# metro_km_walk                float64
# radiation_km                 float64
# price_doc                      int64
# dtype: object

# %%
amostra_teste
# Out:
#           id   timestamp  full_sq  life_sq  floor  max_floor material  \
# 25822  25825  2014-12-04       45     30.0    3.0        5.0      1.0
# 23037  23040  2014-09-29       73     44.0    4.0       17.0      1.0
# 27382  27385  2015-01-20       55     35.0    4.0        5.0      2.0
# 24780  24783  2014-11-15       47     30.0    3.0        9.0      1.0
# 27706  27709  2015-02-04       47     28.0    2.0       12.0      1.0
# ...      ...         ...      ...      ...    ...        ...      ...
# 16646  16649  2014-03-27       46     29.0    8.0        9.0      1.0
# 23753  23756  2014-10-20       57     32.0   10.0       19.0      1.0
# 15536  15539  2014-02-28       38     38.0    3.0       17.0      1.0
# 22504  22507  2014-09-15       53     30.0    3.0       12.0      1.0
# 20397  20400  2014-06-30       46     30.0    5.0        5.0      1.0
#
#        build_year  num_room  kitch_sq  ... work_all ekder_all  kremlin_km  \
# 25822      1964.0       2.0       5.0  ...    93811     32027   10.179723
# 23037      1985.0       3.0      10.0  ...    48620     19712   12.931756
# 27382      1961.0       3.0       5.0  ...    85551     37127   13.255681
# 24780      1978.0       2.0       6.0  ...    98260     41919   14.504257
# 27706      1974.0       2.0       6.0  ...   112133     41985   12.445773
# ...           ...       ...       ...  ...      ...       ...         ...
# 16646      1973.0       2.0       5.0  ...    46080     20036    7.854250
# 23753      2012.0       2.0       8.0  ...     2061       918   27.269874
# 15536         0.0       1.0       0.0  ...     2566       861   22.450272
# 22504      1982.0       2.0       8.0  ...    46080     20036    9.665633
# 20397      1962.0       2.0       5.0  ...    41554     12456   10.757479
#
#        big_road1_km  railroad_km  zd_vokzaly_avto_km  metro_km_avto  \
# 25822      0.969475     0.545758           12.565750       1.604994
# 23037      1.762984     2.541533           13.619835       0.165161
# 27382      1.636755     1.300914           13.674179       1.553650
# 24780      1.073767     2.182843           12.441154       2.500266
# 27706      2.029489     0.969733           10.394751       1.500997
# ...             ...          ...                 ...            ...
# 16646      1.367464     1.072031            7.788046       1.265707
# 23753      0.159237     1.087369           25.016603      13.364620
# 15536      2.855063     1.864007           26.263040       2.285812
# 22504      1.172372     1.101053            9.647924       3.349347
# 20397      1.283421     2.878790           11.723544       1.130535
#
#       metro_km_walk radiation_km  price_doc
# 25822      1.252561     0.854461    2000000
# 23037      0.165161     1.618572   15300000
# 27382      1.553650     1.402411    8600000
# 24780      2.500266     2.310450    2000000
# 27706      1.418041     1.556124    8300000
# ...             ...          ...        ...
# 16646      1.265707     2.515006    7800000
# 23753     13.587830    11.255991    1100000
# 15536      2.285812     9.591465    4358970
# 22504      1.567826     0.859657   10200000
# 20397      0.552387     1.457695    8050000
#
# [5181 rows x 31 columns]

# %%
# Salvando arquivos finais
#dados_final.to_csv('../1. Dados/sberbank_treino.csv')
dados_full_no_out.to_csv('.././1. Dados/sberbank_teste.csv')

# %% [markdown]
# ### Preparação de Dados - Wine

# %%
# Carregando alguns módulos essenciais para trabalharmos os dados

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# Algumas opções do Pandas boas para vermos muitas linhas e colunas de uma vez
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# Carregando os dados
dados = pd.read_csv('../1. Dados/winequalityN.csv')
#dados_teste = pd.read_csv('../1. Dados/dados_treino.csv',index_col=0)

# %%
# Construindo uma target binária
dados['aprovado'] = (dados['quality']>5).astype('int')

# %%
dados_neg = dados[dados.aprovado==0]
dados_pos = dados[dados.aprovado==1].sample(n=len(dados_neg))

# %%
print(len(dados_pos))
print(len(dados_neg))
# Out:
# 2384
# 2384

# %%
dados_final.aprovado.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-256235b24182> in <module>
# ----> 1 dados_final.aprovado.mean()
#
# NameError: name 'dados_final' is not defined

# %%
dados_final = pd.concat([dados_pos,dados_neg]).reset_index()

# %%
dados_final
# Out:
#       index   type  fixed acidity  volatile acidity  citric acid  \
# 0      4205  white            6.7             0.410         0.27
# 1        73  white            8.6             0.230         0.46
# 2      3853  white            6.6             0.320         0.26
# 3      6048    red            8.2             0.330         0.32
# 4      3373  white            6.9             0.280         0.24
# ...     ...    ...            ...               ...          ...
# 4763   6480    red            6.1             0.715         0.10
# 4764   6481    red            6.2             0.460         0.29
# 4765   6487    red            6.6             0.725         0.20
# 4766   6492    red            6.2             0.600         0.08
# 4767   6495    red            5.9             0.645         0.12
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                2.6      0.033                 25.0                  85.0
# 1                1.0      0.054                  9.0                  72.0
# 2                4.6      0.031                 26.0                 120.0
# 3                2.8      0.067                  4.0                  12.0
# 4                2.1      0.034                 49.0                 121.0
# ...              ...        ...                  ...                   ...
# 4763             2.6      0.053                 13.0                  27.0
# 4764             2.1      0.074                 32.0                  98.0
# 4765             7.8      0.073                 29.0                  79.0
# 4766             2.0      0.090                 32.0                  44.0
# 4767             2.0      0.075                 32.0                  44.0
#
#       density    pH  sulphates  alcohol  quality  aprovado
# 0     0.99086  3.05       0.34     11.7        6         1
# 1     0.99410  2.95       0.49      9.1        6         1
# 2     0.99198  3.40       0.73     12.5        7         1
# 3     0.99473  3.30       0.76     12.8        7         1
# 4     0.98882  2.98       0.43     13.2        7         1
# ...       ...   ...        ...      ...      ...       ...
# 4763  0.99362  3.57       0.50     11.9        5         0
# 4764  0.99578  3.33       0.62      9.8        5         0
# 4765  0.99770  3.29       0.54      9.2        5         0
# 4766  0.99490  3.45       0.58     10.5        5         0
# 4767  0.99547  3.57       0.71     10.2        5         0
#
# [4768 rows x 15 columns]

# %%
# Amostrando
dados_teste = dados_final.dropna().sample(frac=0.2,random_state=1234).drop(['index','quality'],axis=1)
dados_treino = dados_final.drop(dados_teste.index).drop(['index','quality'],axis=1)

# %%
dados_teste.head()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 3652  white            6.8              0.22         0.26             1.2
# 3506  white            7.2              0.27         0.37             5.4
# 2499  white            7.0              0.29         0.54            10.7
# 1140  white            7.3              0.41         0.24             6.8
# 3753  white            7.3              0.38         0.23             6.5
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 3652      0.041                 29.0                 182.0  0.99104  3.04
# 3506      0.026                 27.0                 114.0  0.99174  3.13
# 2499      0.046                 59.0                 234.0  0.99660  3.05
# 1140      0.057                 41.0                 163.0  0.99490  3.20
# 3753      0.050                 18.0                 102.0  0.99304  3.10
#
#       sulphates  alcohol  aprovado
# 3652       0.35     11.2         0
# 3506       0.84     12.7         0
# 2499       0.61      9.5         0
# 1140       0.41      9.9         1
# 3753       0.55     11.2         0

# %%
dados_treino.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            6.7              0.41         0.27             2.6
# 1  white            8.6              0.23         0.46             1.0
# 2  white            6.6              0.32         0.26             4.6
# 3    red            8.2              0.33         0.32             2.8
# 4  white            6.9              0.28         0.24             2.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.033                 25.0                  85.0  0.99086  3.05
# 1      0.054                  9.0                  72.0  0.99410  2.95
# 2      0.031                 26.0                 120.0  0.99198  3.40
# 3      0.067                  4.0                  12.0  0.99473  3.30
# 4      0.034                 49.0                 121.0  0.98882  2.98
#
#    sulphates  alcohol  aprovado
# 0       0.34     11.7         1
# 1       0.49      9.1         1
# 2       0.73     12.5         1
# 3       0.76     12.8         1
# 4       0.43     13.2         1

# %%
# Verificando
print(dados_treino.aprovado.mean())
print(dados_teste.aprovado.mean())
# Out:
# 0.4950261780104712
# 0.520042194092827

# %%
# Salvando dados finais
dados_treino.reset_index().to_csv('../1. Dados/transf_wine_treino.csv')
dados_teste.reset_index().to_csv('../1. Dados/transf_wine_teste.csv')
